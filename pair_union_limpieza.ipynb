# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Ejercicios de Limpieza

# %%
df_1 = pd.read_csv("world-data-2023_part1.csv", index_col=0)
df_1.head()
# Out:
#        Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 0  Afghanistan               60           AF                58.10%
# 1      Albania              105           AL                43.10%
# 2      Algeria               18           DZ                17.40%
# 3      Andorra              164           AD                40.00%
# 4       Angola               26           AO                47.50%
#
#   Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 0        652,230           323,000       32.49          93.0
# 1         28,748             9,000       11.78         355.0
# 2      2,381,741           317,000       24.28         213.0
# 3            468               NaN        7.20         376.0
# 4      1,246,700           117,000       40.73         244.0
#
#   Capital/Major City Co2-Emissions     CPI CPI Change (%) Currency-Code  \
# 0              Kabul         8,672   149.9          2.30%           AFN
# 1             Tirana         4,536  119.05          1.40%           ALL
# 2            Algiers       150,006  151.36          2.00%           DZD
# 3   Andorra la Vella           469     NaN            NaN           EUR
# 4             Luanda        34,693  261.73         17.10%           AOA
#
#    Fertility Rate Forested Area (%) Gasoline Price
# 0            4.47             2.10%         $0.70
# 1            1.62            28.10%         $1.36
# 2            3.02             0.80%         $0.28
# 3            1.27            34.00%         $1.51
# 4            5.52            46.30%         $0.97

# %%
df_2 = pd.read_csv("world-data-2023_part2.csv", index_col=0)
df_2.head()
# Out:
#                  GDP Gross primary education enrollment (%)  \
# 0   $19,101,353,833                                 104.00%
# 1   $15,278,077,447                                 107.00%
# 2  $169,988,236,398                                 109.90%
# 3    $3,154,057,987                                 106.40%
# 4   $94,635,415,870                                 113.50%
#
#   Gross tertiary education enrollment (%)  Infant mortality      Largest city  \
# 0                                   9.70%              47.9             Kabul
# 1                                  55.00%               7.8            Tirana
# 2                                  51.40%              20.1           Algiers
# 3                                     NaN               2.7  Andorra la Vella
# 4                                   9.30%              51.6            Luanda
#
#    Life expectancy  Maternal mortality ratio Minimum wage Official language  \
# 0             64.5                     638.0       $0.43             Pashto
# 1             78.5                      15.0       $1.12           Albanian
# 2             76.7                     112.0       $0.95             Arabic
# 3              NaN                       NaN       $6.63            Catalan
# 4             60.8                     241.0       $0.71         Portuguese
#
#   Out of pocket health expenditure  Physicians per thousand  Population  \
# 0                           78.40%                     0.28  38,041,754
# 1                           56.90%                     1.20   2,854,191
# 2                           28.10%                     1.72  43,053,054
# 3                           36.40%                     3.33      77,142
# 4                           33.40%                     0.21  31,825,295
#
#   Population: Labor force participation (%) Tax revenue (%) Total tax rate  \
# 0                                    48.90%           9.30%         71.40%
# 1                                    55.70%          18.60%         36.60%
# 2                                    41.20%          37.20%         66.10%
# 3                                       NaN             NaN            NaN
# 4                                    77.50%           9.20%         49.10%
#
#   Unemployment rate Urban_population      country  \
# 0            11.12%        9,797,273  Afghanistan
# 1            12.33%        1,747,593      Albania
# 2            11.70%       31,510,100      Algeria
# 3               NaN           67,873      Andorra
# 4             6.89%       21,061,025       Angola
#
#                     coordinates
# 0    ('33.93911 ', '67.709953')
# 1   ('41.153332 ', '20.168331')
# 2    ('28.033886 ', '1.659626')
# 3    ('42.506285 ', '1.521801')
# 4  ('-11.202692 ', '17.873887')

# %%
df_1.sample(5)
# Out:
#          Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 157     Slovakia              114           SK                39.20%
# 0    Afghanistan               60           AF                58.10%
# 55       Estonia               31           EE                23.10%
# 18         Benin              108           BJ                33.30%
# 34          Chad               13           TD                39.70%
#
#     Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 157         49,035            16,000       10.60         421.0
# 0          652,230           323,000       32.49          93.0
# 55          45,228             6,000       10.90         372.0
# 18         112,622            12,000       36.22         229.0
# 34       1,284,000            35,000       42.17         235.0
#
#     Capital/Major City Co2-Emissions     CPI CPI Change (%) Currency-Code  \
# 157         Bratislava        32,424  115.34          2.70%           EUR
# 0                Kabul         8,672   149.9          2.30%           AFN
# 55             Tallinn        16,590  122.14          2.30%           EUR
# 18          Porto-Novo         6,476  110.71         -0.90%           XOF
# 34           N'Djamena         1,016   117.7         -1.00%           XAF
#
#      Fertility Rate Forested Area (%) Gasoline Price
# 157            1.52            40.40%         $1.32
# 0              4.47             2.10%         $0.70
# 55             1.59            51.30%         $1.14
# 18             4.84            37.80%         $0.72
# 34             5.75             3.80%         $0.78

# %%
df_2.sample(5)
# Out:
#                    GDP Gross primary education enrollment (%)  \
# 50   $107,435,665,000                                 103.30%
# 97    $52,076,250,948                                 109.00%
# 22    $18,340,510,789                                 103.20%
# 148      $850,655,017                                 110.50%
# 128   $10,220,781,069                                     NaN
#
#     Gross tertiary education enrollment (%)  Infant mortality Largest city  \
# 50                                   44.90%              12.2        Quito
# 97                                   60.50%              10.2          NaN
# 22                                   24.90%              30.0     Gaborone
# 148                                   7.60%              13.6         Apia
# 128                                     NaN               NaN       Skopje
#
#      Life expectancy  Maternal mortality ratio Minimum wage Official language  \
# 50              76.8                      59.0       $2.46            Spanish
# 97              72.7                      72.0       $1.88             Arabic
# 22              69.3                     144.0       $0.29            English
# 148             73.2                      43.0       $0.78             Samoan
# 128              NaN                       NaN          NaN        Macedonian
#
#     Out of pocket health expenditure  Physicians per thousand  Population  \
# 50                            43.70%                     2.04  17,373,662
# 97                            36.70%                     2.09   6,777,452
# 22                             5.30%                     0.37   2,346,179
# 148                           11.50%                     0.34     202,506
# 128                           35.60%                      NaN   1,836,713
#
#     Population: Labor force participation (%) Tax revenue (%) Total tax rate  \
# 50                                     68.00%             NaN         34.40%
# 97                                     49.70%             NaN         32.60%
# 22                                     70.80%          19.50%         25.10%
# 148                                    43.70%          25.50%         19.30%
# 128                                       NaN             NaN            NaN
#
#     Unemployment rate Urban_population          country  \
# 50              3.97%       11,116,711          Ecuador
# 97             18.56%        5,448,597            Libya
# 22             18.19%        1,616,550         Botswana
# 148             8.36%           35,588            Samoa
# 128               NaN              NaN  North Macedonia
#
#                         coordinates
# 50     ('-1.831239 ', '-78.183406')
# 97        ('26.3351 ', '17.228331')
# 22     ('-22.328474 ', '24.684866')
# 148  ('-13.759029 ', '-172.104629')
# 128     ('41.608635 ', '21.745275')

# %%
df_1.shape
# Out:
# (195, 16)

# %%
df_2.shape
# Out:
# (195, 19)

# %%
df_merge = df_1.merge(df_2, how='inner', left_on="Country", right_on="country")

df_merge.head(2)
# Out:
#        Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 0  Afghanistan               60           AF                58.10%
# 1      Albania              105           AL                43.10%
#
#   Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 0        652,230           323,000       32.49          93.0
# 1         28,748             9,000       11.78         355.0
#
#   Capital/Major City Co2-Emissions     CPI CPI Change (%) Currency-Code  \
# 0              Kabul         8,672   149.9          2.30%           AFN
# 1             Tirana         4,536  119.05          1.40%           ALL
#
#    Fertility Rate Forested Area (%) Gasoline Price               GDP  \
# 0            4.47             2.10%         $0.70   $19,101,353,833
# 1            1.62            28.10%         $1.36   $15,278,077,447
#
#   Gross primary education enrollment (%)  \
# 0                                104.00%
# 1                                107.00%
#
#   Gross tertiary education enrollment (%)  Infant mortality Largest city  \
# 0                                   9.70%              47.9        Kabul
# 1                                  55.00%               7.8       Tirana
#
#    Life expectancy  Maternal mortality ratio Minimum wage Official language  \
# 0             64.5                     638.0       $0.43             Pashto
# 1             78.5                      15.0       $1.12           Albanian
#
#   Out of pocket health expenditure  Physicians per thousand  Population  \
# 0                           78.40%                     0.28  38,041,754
# 1                           56.90%                     1.20   2,854,191
#
#   Population: Labor force participation (%) Tax revenue (%) Total tax rate  \
# 0                                    48.90%           9.30%         71.40%
# 1                                    55.70%          18.60%         36.60%
#
#   Unemployment rate Urban_population      country                  coordinates
# 0            11.12%        9,797,273  Afghanistan   ('33.93911 ', '67.709953')
# 1            12.33%        1,747,593      Albania  ('41.153332 ', '20.168331')

# %% [markdown]
# 1. Después de la unión de datos, tenemos dos columnas de "country". Elimina una de ellas.

# %%
df_merge.drop("country", axis=1, inplace=True)
df_merge.head(2)
# Out:
#        Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 0  Afghanistan               60           AF                58.10%
# 1      Albania              105           AL                43.10%
#
#   Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 0        652,230           323,000       32.49          93.0
# 1         28,748             9,000       11.78         355.0
#
#   Capital/Major City Co2-Emissions     CPI CPI Change (%) Currency-Code  \
# 0              Kabul         8,672   149.9          2.30%           AFN
# 1             Tirana         4,536  119.05          1.40%           ALL
#
#    Fertility Rate Forested Area (%) Gasoline Price               GDP  \
# 0            4.47             2.10%         $0.70   $19,101,353,833
# 1            1.62            28.10%         $1.36   $15,278,077,447
#
#   Gross primary education enrollment (%)  \
# 0                                104.00%
# 1                                107.00%
#
#   Gross tertiary education enrollment (%)  Infant mortality Largest city  \
# 0                                   9.70%              47.9        Kabul
# 1                                  55.00%               7.8       Tirana
#
#    Life expectancy  Maternal mortality ratio Minimum wage Official language  \
# 0             64.5                     638.0       $0.43             Pashto
# 1             78.5                      15.0       $1.12           Albanian
#
#   Out of pocket health expenditure  Physicians per thousand  Population  \
# 0                           78.40%                     0.28  38,041,754
# 1                           56.90%                     1.20   2,854,191
#
#   Population: Labor force participation (%) Tax revenue (%) Total tax rate  \
# 0                                    48.90%           9.30%         71.40%
# 1                                    55.70%          18.60%         36.60%
#
#   Unemployment rate Urban_population                  coordinates
# 0            11.12%        9,797,273   ('33.93911 ', '67.709953')
# 1            12.33%        1,747,593  ('41.153332 ', '20.168331')

# %% [markdown]
# 2. Los nombres de las columnas no son homogeneos. Cambia los nombres de las columnas de tal forma que:
# - No tengan espacios.
# - Estén en minúscula.
# - No tengan paréntesis, es decir, quitar "(%)", "(Km2)".
# - Algunas columnas tiene "\n". Eliminalos de los nombres de las columnas.
# - Algunas columnas tienen ":". Eliminalos de los nombres de las columnas.

# %%
nuevas_columnas = {columna: columna.lower().replace(" ", "_").replace("\n", "").replace(":", "_") for columna in df_merge.columns}

# %%
nuevas_columnas
# Out:
# {'Country': 'country',
#  'Density\n(P/Km2)': 'density(p/km2)',
#  'Abbreviation': 'abbreviation',
#  'Agricultural Land( %)': 'agricultural_land(_%)',
#  'Land Area(Km2)': 'land_area(km2)',
#  'Armed Forces size': 'armed_forces_size',
#  'Birth Rate': 'birth_rate',
#  'Calling Code': 'calling_code',
#  'Capital/Major City': 'capital/major_city',
#  'Co2-Emissions': 'co2-emissions',
#  'CPI': 'cpi',
#  'CPI Change (%)': 'cpi_change_(%)',
#  'Currency-Code': 'currency-code',
#  'Fertility Rate': 'fertility_rate',
#  'Forested Area (%)': 'forested_area_(%)',
#  'Gasoline Price': 'gasoline_price',
#  'GDP': 'gdp',
#  'Gross primary education enrollment (%)': 'gross_primary_education_enrollment_(%)',
#  'Gross tertiary education enrollment (%)': 'gross_tertiary_education_enrollment_(%)',
#  'Infant mortality': 'infant_mortality',
#  'Largest city': 'largest_city',
#  'Life expectancy': 'life_expectancy',
#  'Maternal mortality ratio': 'maternal_mortality_ratio',
#  'Minimum wage': 'minimum_wage',
#  'Official language': 'official_language',
#  'Out of pocket health expenditure': 'out_of_pocket_health_expenditure',
#  'Physicians per thousand': 'physicians_per_thousand',
#  'Population': 'population',
#  'Population: Labor force participation (%)': 'population__labor_force_participation_(%)',
#  'Tax revenue (%)': 'tax_revenue_(%)',
#  'Total tax rate': 'total_tax_rate',
#  'Unemployment rate': 'unemployment_rate',
#  'Urban_population': 'urban_population',
#  'coordinates': 'coordinates'}

# %%
df_merge.rename(columns = nuevas_columnas, inplace = True)

# comprobamos que se han cambiado los nombres de las columnas
df_merge.head(1)
# Out:
#        country density(p/km2) abbreviation agricultural_land(_%)  \
# 0  Afghanistan             60           AF                58.10%
#
#   land_area(km2) armed_forces_size  birth_rate  calling_code  \
# 0        652,230           323,000       32.49          93.0
#
#   capital/major_city co2-emissions    cpi cpi_change_(%) currency-code  \
# 0              Kabul         8,672  149.9          2.30%           AFN
#
#    fertility_rate forested_area_(%) gasoline_price               gdp  \
# 0            4.47             2.10%         $0.70   $19,101,353,833
#
#   gross_primary_education_enrollment_(%)  \
# 0                                104.00%
#
#   gross_tertiary_education_enrollment_(%)  infant_mortality largest_city  \
# 0                                   9.70%              47.9        Kabul
#
#    life_expectancy  maternal_mortality_ratio minimum_wage official_language  \
# 0             64.5                     638.0       $0.43             Pashto
#
#   out_of_pocket_health_expenditure  physicians_per_thousand  population  \
# 0                           78.40%                     0.28  38,041,754
#
#   population__labor_force_participation_(%) tax_revenue_(%) total_tax_rate  \
# 0                                    48.90%           9.30%         71.40%
#
#   unemployment_rate urban_population                 coordinates
# 0            11.12%        9,797,273  ('33.93911 ', '67.709953')

# %%
# Solución parcial a la que habíamos llegado:

# nuevas_columnas = {columna: columna.lower().replace(" ", "_").replace("\n", "").replace(":", "_") for columna in df_merge.columns}

# %%
columnas = df_merge.columns
nuevas_columnas = {col: col.split("(")[0].strip().replace(" ", "_").replace("\n", "").replace(":", "").lower() for col in columnas}
df_merge.rename(columns=nuevas_columnas, inplace = True)

# %%
df_merge.head(2)
# Out:
#        country density abbreviation agricultural_land land_area  \
# 0  Afghanistan      60           AF            58.10%   652,230
# 1      Albania     105           AL            43.10%    28,748
#
#   armed_forces_size  birth_rate  calling_code capital/major_city  \
# 0           323,000       32.49          93.0              Kabul
# 1             9,000       11.78         355.0             Tirana
#
#   co2-emissions     cpi cpi_change_ currency-code  fertility_rate  \
# 0         8,672   149.9       2.30%           AFN            4.47
# 1         4,536  119.05       1.40%           ALL            1.62
#
#   forested_area_ gasoline_price               gdp  \
# 0          2.10%         $0.70   $19,101,353,833
# 1         28.10%         $1.36   $15,278,077,447
#
#   gross_primary_education_enrollment_ gross_tertiary_education_enrollment_  \
# 0                             104.00%                                9.70%
# 1                             107.00%                               55.00%
#
#    infant_mortality largest_city  life_expectancy  maternal_mortality_ratio  \
# 0              47.9        Kabul             64.5                     638.0
# 1               7.8       Tirana             78.5                      15.0
#
#   minimum_wage official_language out_of_pocket_health_expenditure  \
# 0       $0.43             Pashto                           78.40%
# 1       $1.12           Albanian                           56.90%
#
#    physicians_per_thousand  population population__labor_force_participation_  \
# 0                     0.28  38,041,754                                 48.90%
# 1                     1.20   2,854,191                                 55.70%
#
#   tax_revenue_ total_tax_rate unemployment_rate urban_population  \
# 0        9.30%         71.40%            11.12%        9,797,273
# 1       18.60%         36.60%            12.33%        1,747,593
#
#                    coordinates
# 0   ('33.93911 ', '67.709953')
# 1  ('41.153332 ', '20.168331')

# %% [markdown]
# 3. La columnas coordinates tiene la latitud y la longitud en una sola columna. Crea dos columnas nuevas, una con la longitud y otra con la latitud. Una vez hecho, elimina la columna de coordinates.

# %% [markdown]
# 4. Las columnas unemployment_rate, total_tax_rate, tax_revenue, population_labor_force_participation, out_of_pocket_health_expenditure, gross_tertiary_education_enrollment, gross_primary_education_enrollment, forested_area, cpi_change, agricultural_land tienen "%". Elimina los "%" de los valores de las columnas.

# %% [markdown]
# 5. Haz lo mismo para las columnas de gasoline_price, gdp, minimum_wage, pero eliminando "$".

# %% [markdown]
# 6. Guarda el DataFrame para usarlo posteriormente.

# %% [markdown]
# ## Ejercicios de Filtrado
# 1. Encuentra todos los países cuya mortalidad infantil esté entre 40 y 50 personas por kilómetro cuadrado.

# %% [markdown]
# 2. Encuentra los países cuyas tasas de natalidad son mayores o iguales a 20 y su esperanza de vida es mayor de 75 años.

# %% [markdown]
# 3. Encuentra las ciudades cuyos paises contienen la palabra "la" en su nombre.

# %% [markdown]
# 4. Encuentra los países cuyos medicos por cada 1000 habitantes (physicians_per_thousand) sea mayores de 5.

# %% [markdown]
# 5. Encuentra los países cuyatasa de fertilidad sea mayor a 6.

# %% [markdown]
# 6. Encuentra los países cuya moneda es el euro (EUR) y tienen una tasa de natalidad superior al promedio.

# %% [markdown]
# 7. Encuentra los países cuyas tasas de mortalidad infantil son superiores a 70
