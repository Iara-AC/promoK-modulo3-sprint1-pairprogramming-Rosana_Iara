# %%
# importamos la pandas para poder trabajar en la lección
import pandas as pd

# %% [markdown]
# Pair EDA

# %% [markdown]
# 1) Muestra las primeras 5 filas del conjunto de datos.

# %%
# importamos un nuevo fichero de datos
df = pd.read_csv("world-data-2023_part1.csv", index_col=0)
df.head(5)
# Out:
#        Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 0  Afghanistan               60           AF                58.10%
# 1      Albania              105           AL                43.10%
# 2      Algeria               18           DZ                17.40%
# 3      Andorra              164           AD                40.00%
# 4       Angola               26           AO                47.50%
#
#   Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 0        652,230           323,000       32.49          93.0
# 1         28,748             9,000       11.78         355.0
# 2      2,381,741           317,000       24.28         213.0
# 3            468               NaN        7.20         376.0
# 4      1,246,700           117,000       40.73         244.0
#
#   Capital/Major City Co2-Emissions     CPI CPI Change (%) Currency-Code  \
# 0              Kabul         8,672   149.9          2.30%           AFN
# 1             Tirana         4,536  119.05          1.40%           ALL
# 2            Algiers       150,006  151.36          2.00%           DZD
# 3   Andorra la Vella           469     NaN            NaN           EUR
# 4             Luanda        34,693  261.73         17.10%           AOA
#
#    Fertility Rate Forested Area (%) Gasoline Price
# 0            4.47             2.10%         $0.70
# 1            1.62            28.10%         $1.36
# 2            3.02             0.80%         $0.28
# 3            1.27            34.00%         $1.51
# 4            5.52            46.30%         $0.97

# %% [markdown]
# 2) Muestra las últimas 5 filas del conjunto de datos.

# %%
df.tail(5)
# Out:
#        Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 190  Venezuela               32           VE                24.50%
# 191    Vietnam              314           VN                39.30%
# 192      Yemen               56           YE                44.60%
# 193     Zambia               25           ZM                32.10%
# 194   Zimbabwe               38           ZW                41.90%
#
#     Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 190        912,050           343,000       17.88          58.0
# 191        331,210           522,000       16.75          84.0
# 192        527,968            40,000       30.45         967.0
# 193        752,618            16,000       36.19         260.0
# 194        390,757            51,000       30.68         263.0
#
#     Capital/Major City Co2-Emissions       CPI CPI Change (%) Currency-Code  \
# 190            Caracas       164,175  2,740.27        254.90%           VED
# 191              Hanoi       192,668    163.52          2.80%           VND
# 192              Sanaa        10,609    157.58          8.10%           YER
# 193             Lusaka         5,141    212.31          9.20%           ZMW
# 194             Harare        10,983    105.51          0.90%           NaN
#
#      Fertility Rate Forested Area (%) Gasoline Price
# 190            2.27            52.70%         $0.00
# 191            2.05            48.10%         $0.80
# 192            3.79             1.00%         $0.92
# 193            4.63            65.20%         $1.40
# 194            3.62            35.50%         $1.34

# %% [markdown]
# 3) Muestra una muestra aleatoria de 5 filas del conjunto de datos.

# %%
df.sample(5)
# Out:
#          Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 142      Romania               84           RO                58.80%
# 68     Guatemala              167           GT                36.00%
# 122  Netherlands              508           NL                53.30%
# 192        Yemen               56           YE                44.60%
# 76       Iceland                3           IS                18.70%
#
#     Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 142        238,391           126,000        9.60          40.0
# 68         108,889            43,000       24.56         502.0
# 122         41,543            41,000        9.70          31.0
# 192        527,968            40,000       30.45         967.0
# 76         103,000                 0       12.00         354.0
#
#     Capital/Major City Co2-Emissions     CPI CPI Change (%) Currency-Code  \
# 142          Bucharest        69,259  123.78          3.80%           RON
# 68      Guatemala City        16,777  142.92          3.70%           GTQ
# 122          Amsterdam       170,780  115.91          2.60%           NaN
# 192              Sanaa        10,609  157.58          8.10%           YER
# 76           Reykjav��         2,065     129          3.00%           ISK
#
#      Fertility Rate Forested Area (%) Gasoline Price
# 142            1.71            30.10%         $1.16
# 68             2.87            32.70%         $0.79
# 122            1.59            11.20%         $1.68
# 192            3.79             1.00%         $0.92
# 76             1.71             0.50%         $1.69

# %% [markdown]
# 4)Muestra el nombre de todas las columnas en el conjunto de datos.

# %%
df.columns
# Out:
# Index(['Country', 'Density\n(P/Km2)', 'Abbreviation', 'Agricultural Land( %)',
#        'Land Area(Km2)', 'Armed Forces size', 'Birth Rate', 'Calling Code',
#        'Capital/Major City', 'Co2-Emissions', 'CPI', 'CPI Change (%)',
#        'Currency-Code', 'Fertility Rate', 'Forested Area (%)',
#        'Gasoline Price'],
#       dtype='object')

# %% [markdown]
# 5) Muestra los valores únicos en la columna "Abbreviation".

# %%
df['Abbreviation'].unique()
# Out:
# array(['AF', 'AL', 'DZ', 'AD', 'AO', 'AG', 'AR', 'AM', 'AU', 'AT', 'AZ',
#        'BS', 'BH', 'BD', 'BB', 'BY', 'BE', 'BZ', 'BJ', 'BT', 'BO', 'BA',
#        'BW', 'BR', 'BN', 'BG', 'BF', 'BI', 'CI', 'CV', 'KH', 'CM', 'CA',
#        'CF', 'TD', 'CL', 'CN', 'CO', 'KM', nan, 'CR', 'HR', 'CU', 'CY',
#        'CZ', 'CD', 'DK', 'DJ', 'DM', 'DO', 'EC', 'EG', 'SV', 'GQ', 'ER',
#        'EE', 'ET', 'FJ', 'FI', 'FR', 'GA', 'GM', 'GE', 'DE', 'GH', 'GR',
#        'GD', 'GT', 'GN', 'GW', 'GY', 'HT', 'HN', 'HU', 'IS', 'IN', 'ID',
#        'IR', 'IQ', 'IL', 'IT', 'JM', 'JP', 'JO', 'KZ', 'KE', 'KI', 'KW',
#        'KG', 'LA', 'LV', 'LB', 'LS', 'LR', 'LY', 'LI', 'LT', 'LU', 'MG',
#        'MW', 'MY', 'MV', 'ML', 'MT', 'MH', 'MR', 'MU', 'MX', 'FM', 'MD',
#        'MC', 'MN', 'ME', 'MA', 'MZ', 'MM', 'NR', 'NP', 'NL', 'NZ', 'NI',
#        'NE', 'NG', 'KP', 'NO', 'OM', 'PK', 'PW', 'PA', 'PG', 'PY', 'PE',
#        'PH', 'PL', 'PT', 'QA', 'RO', 'RU', 'RW', 'KN', 'LC', 'VC', 'WS',
#        'SM', 'ST', 'SA', 'SN', 'RS', 'SC', 'SL', 'SG', 'SK', 'SI', 'SB',
#        'SO', 'ZA', 'KR', 'SS', 'ES', 'LK', 'SD', 'SR', 'SE', 'CH', 'SY',
#        'TJ', 'TZ', 'TH', 'TL', 'TG', 'TO', 'TT', 'TN', 'TR', 'TM', 'TV',
#        'UG', 'UA', 'AE', 'GB', 'US', 'UY', 'UZ', 'VU', 'VE', 'VN', 'YE',
#        'ZM', 'ZW'], dtype=object)

# %% [markdown]
# BONUS DE EXPLORACION

# %% [markdown]
# 1) Cuenta cuántas veces aparece cada valor único en la columna "Abbreviation".

# %%
df['Abbreviation'].value_counts()
# Out:
# Abbreviation
# AF    1
# PY    1
# NE    1
# NG    1
# KP    1
#      ..
# GR    1
# GD    1
# GT    1
# GN    1
# ZW    1
# Name: count, Length: 188, dtype: int64

# %% [markdown]
# 2) Verifica si hay valores nulos en el conjunto de datos.

# %%
df.isna().sum()
# Out:
# Country                   0
# Density\n(P/Km2)          0
# Abbreviation              7
# Agricultural Land( %)     7
# Land Area(Km2)            1
# Armed Forces size        24
# Birth Rate                6
# Calling Code              1
# Capital/Major City        3
# Co2-Emissions             7
# CPI                      17
# CPI Change (%)           16
# Currency-Code            15
# Fertility Rate            7
# Forested Area (%)         7
# Gasoline Price           20
# dtype: int64

# %% [markdown]
# 3) Verifica si hay valores no nulos en el conjunto de datos.

# %%
df.notnull().sum()
# Out:
# Country                  195
# Density\n(P/Km2)         195
# Abbreviation             188
# Agricultural Land( %)    188
# Land Area(Km2)           194
# Armed Forces size        171
# Birth Rate               189
# Calling Code             194
# Capital/Major City       192
# Co2-Emissions            188
# CPI                      178
# CPI Change (%)           179
# Currency-Code            180
# Fertility Rate           188
# Forested Area (%)        188
# Gasoline Price           175
# dtype: int64

# %% [markdown]
# 4) Muestra información general sobre el conjunto de datos.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 195 entries, 0 to 194
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Country                195 non-null    object
#  1   Density
# (P/Km2)        195 non-null    object
#  2   Abbreviation           188 non-null    object
#  3   Agricultural Land( %)  188 non-null    object
#  4   Land Area(Km2)         194 non-null    object
#  5   Armed Forces size      171 non-null    object
#  6   Birth Rate             189 non-null    float64
#  7   Calling Code           194 non-null    float64
#  8   Capital/Major City     192 non-null    object
#  9   Co2-Emissions          188 non-null    object
#  10  CPI                    178 non-null    object
#  11  CPI Change (%)         179 non-null    object
#  12  Currency-Code          180 non-null    object
#  13  Fertility Rate         188 non-null    float64
#  14  Forested Area (%)      188 non-null    object
#  15  Gasoline Price         175 non-null    object
# dtypes: float64(3), object(13)
# memory usage: 25.9+ KB

# %% [markdown]
# 5)Elimina una columna específica (por ejemplo, "Armed Forces size").

# %%
df.drop(['Armed Forces size'], axis=1, inplace=True)

# %%
df.head()
# Out:
#        Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 0  Afghanistan               60           AF                58.10%
# 1      Albania              105           AL                43.10%
# 2      Algeria               18           DZ                17.40%
# 3      Andorra              164           AD                40.00%
# 4       Angola               26           AO                47.50%
#
#   Land Area(Km2)  Birth Rate  Calling Code Capital/Major City Co2-Emissions  \
# 0        652,230       32.49          93.0              Kabul         8,672
# 1         28,748       11.78         355.0             Tirana         4,536
# 2      2,381,741       24.28         213.0            Algiers       150,006
# 3            468        7.20         376.0   Andorra la Vella           469
# 4      1,246,700       40.73         244.0             Luanda        34,693
#
#       CPI CPI Change (%) Currency-Code  Fertility Rate Forested Area (%)  \
# 0   149.9          2.30%           AFN            4.47             2.10%
# 1  119.05          1.40%           ALL            1.62            28.10%
# 2  151.36          2.00%           DZD            3.02             0.80%
# 3     NaN            NaN           EUR            1.27            34.00%
# 4  261.73         17.10%           AOA            5.52            46.30%
#
#   Gasoline Price
# 0         $0.70
# 1         $1.36
# 2         $0.28
# 3         $1.51
# 4         $0.97

# %%
df.columns
# Out:
# Index(['Country', 'Density\n(P/Km2)', 'Abbreviation', 'Agricultural Land( %)',
#        'Land Area(Km2)', 'Birth Rate', 'Calling Code', 'Capital/Major City',
#        'Co2-Emissions', 'CPI', 'CPI Change (%)', 'Currency-Code',
#        'Fertility Rate', 'Forested Area (%)', 'Gasoline Price'],
#       dtype='object')

# %% [markdown]
# 6) Selecciona las columnas numéricas del conjunto de datos y muestra sus estadísticas descriptivas básicas (para esto tendréis que usar el método '.describe(), su documentación la tenéis aquí).

# %%
df.describe().T
# Out:
#                 count        mean         std   min     25%      50%  \
# Birth Rate      189.0   20.214974    9.945774  5.90  11.300   17.950
# Calling Code    194.0  360.546392  323.236419  1.00  82.500  255.500
# Fertility Rate  188.0    2.698138    1.282267  0.98   1.705    2.245
#
#                      75%      max
# Birth Rate       28.7500    46.08
# Calling Code    506.7500  1876.00
# Fertility Rate    3.5975     6.91

# %% [markdown]
# Ejercicios con loc e iloc

# %% [markdown]
# 1) Selecciona todas las columnas de las filas 2 a 4 (inclusive) utilizando loc.

# %%
df.loc[2:4,:]
# Out:
#    Country Density\n(P/Km2) Abbreviation Agricultural Land( %) Land Area(Km2)  \
# 2  Algeria               18           DZ                17.40%      2,381,741
# 3  Andorra              164           AD                40.00%            468
# 4   Angola               26           AO                47.50%      1,246,700
#
#    Birth Rate  Calling Code Capital/Major City Co2-Emissions     CPI  \
# 2       24.28         213.0            Algiers       150,006  151.36
# 3        7.20         376.0   Andorra la Vella           469     NaN
# 4       40.73         244.0             Luanda        34,693  261.73
#
#   CPI Change (%) Currency-Code  Fertility Rate Forested Area (%)  \
# 2          2.00%           DZD            3.02             0.80%
# 3            NaN           EUR            1.27            34.00%
# 4         17.10%           AOA            5.52            46.30%
#
#   Gasoline Price
# 2         $0.28
# 3         $1.51
# 4         $0.97

# %% [markdown]
# 2) Utilizando loc, filtra el conjunto de datos para mostrar solo las filas donde la densidad (columna "Birth Rate") es mayor a 30.

# %%
df.loc[df['Birth Rate']>30, :]
# Out:
#                               Country Density\n(P/Km2) Abbreviation  \
# 0                         Afghanistan               60           AF
# 4                              Angola               26           AO
# 18                              Benin              108           BJ
# 26                       Burkina Faso               76           BF
# 27                            Burundi              463           BI
# 28                        Ivory Coast               83           CI
# 31                           Cameroon               56           CM
# 33           Central African Republic                8           CF
# 34                               Chad               13           TD
# 38                            Comoros              467           KM
# 39              Republic of the Congo               16          NaN
# 45   Democratic Republic of the Congo               40           CD
# 53                  Equatorial Guinea               50           GQ
# 54                            Eritrea               35           ER
# 57                           Ethiopia              115           ET
# 61                              Gabon                9           GA
# 62                         The Gambia              239           GM
# 69                             Guinea               53           GN
# 70                      Guinea-Bissau               70           GW
# 96                            Liberia               53           LR
# 101                        Madagascar               48           MG
# 102                            Malawi              203           MW
# 105                              Mali               17           ML
# 108                        Mauritania                5           MR
# 117                        Mozambique               40           MZ
# 125                             Niger               19           NE
# 126                           Nigeria              226           NG
# 144                            Rwanda              525           RW
# 150                      S�����������              228           ST
# 152                           Senegal               87           SN
# 155                      Sierra Leone              111           SL
# 159                   Solomon Islands               25           SB
# 160                           Somalia               25           SO
# 163                       South Sudan               18           SS
# 166                             Sudan               25           SD
# 171                        Tajikistan               68           TJ
# 172                          Tanzania               67           TZ
# 175                              Togo              152           TG
# 182                            Uganda              229           UG
# 192                             Yemen               56           YE
# 193                            Zambia               25           ZM
# 194                          Zimbabwe               38           ZW
#
#     Agricultural Land( %) Land Area(Km2)  Birth Rate  Calling Code  \
# 0                  58.10%        652,230       32.49          93.0
# 4                  47.50%      1,246,700       40.73         244.0
# 18                 33.30%        112,622       36.22         229.0
# 26                 44.20%        274,200       37.93         226.0
# 27                 79.20%         27,830       39.01         257.0
# 28                 64.80%        322,463       35.74         225.0
# 31                 20.60%        475,440       35.39         237.0
# 33                  8.20%        622,984       35.35         236.0
# 34                 39.70%      1,284,000       42.17         235.0
# 38                 71.50%          2,235       31.88         269.0
# 39                 31.10%        342,000       32.86         242.0
# 45                 11.60%      2,344,858       41.18         243.0
# 53                 10.10%         28,051       33.24         240.0
# 54                 75.20%        117,600       30.30         291.0
# 57                 36.30%      1,104,300       32.34         251.0
# 61                 20.00%        267,667       31.61         241.0
# 62                 59.80%         11,300       38.54         220.0
# 69                 59.00%        245,857       36.36         224.0
# 70                 58.00%         36,125       35.13         245.0
# 96                 28.00%        111,369       33.04         231.0
# 101                71.20%        587,041       32.66         261.0
# 102                61.40%        118,484       34.12         265.0
# 105                33.80%      1,240,192       41.54         223.0
# 108                38.50%      1,030,700       33.69         222.0
# 117                63.50%        799,380       37.52         258.0
# 125                36.10%      1,267,000       46.08         227.0
# 126                77.70%        923,768       37.91         234.0
# 144                73.40%         26,338       31.70         250.0
# 150                50.70%            964       31.54         239.0
# 152                46.10%        196,722       34.52         221.0
# 155                54.70%         71,740       33.41         232.0
# 159                 3.90%         28,896       32.44         677.0
# 160                70.30%        637,657       41.75         252.0
# 163                   NaN        644,329       35.01         211.0
# 166                28.70%      1,861,484       32.18         249.0
# 171                34.10%        144,100       30.76         992.0
# 172                44.80%        947,300       36.70         255.0
# 175                70.20%         56,785       33.11         228.0
# 182                71.90%        241,038       38.14         256.0
# 192                44.60%        527,968       30.45         967.0
# 193                32.10%        752,618       36.19         260.0
# 194                41.90%        390,757       30.68         263.0
#
#     Capital/Major City Co2-Emissions       CPI CPI Change (%) Currency-Code  \
# 0                Kabul         8,672     149.9          2.30%           AFN
# 4               Luanda        34,693    261.73         17.10%           AOA
# 18          Porto-Novo         6,476    110.71         -0.90%           XOF
# 26         Ouagadougou         3,418    106.58         -3.20%           XOF
# 27           Bujumbura           495    182.11         -0.70%           BIF
# 28        Yamoussoukro         9,674    111.61         -0.90%           XOF
# 31             Yaound�         8,291    118.65          2.50%           XAF
# 33              Bangui           297    186.86         37.10%           NaN
# 34           N'Djamena         1,016     117.7         -1.00%           XAF
# 38     Moroni, Comoros           202    103.62         -4.30%           KMF
# 39         Brazzaville         3,282    124.74          2.20%           XAF
# 45            Kinshasa         2,021    133.85          2.90%           CDF
# 53              Malabo         5,655    124.35          1.20%           XAF
# 54              Asmara           711       NaN            NaN           ERN
# 57         Addis Ababa        14,870    143.86         15.80%           ETB
# 61          Libreville         5,321    122.19          2.10%           XAF
# 62              Banjul           532    172.73          7.10%           GMD
# 69             Conakry         2,996    262.95          9.50%           GNF
# 70              Bissau           293    111.65          1.40%           XOF
# 96            Monrovia         1,386    223.13         23.60%           NaN
# 101       Antananarivo         3,905    184.33          5.60%           MGA
# 102           Lilongwe         1,298    418.34          9.40%           MWK
# 105             Bamako         3,179    108.73         -1.70%           XOF
# 108         Nouakchott         2,739    135.02          2.30%           MRU
# 117             Maputo         7,943    182.31          2.80%           MZN
# 125             Niamey         2,017    109.32         -2.50%           XOF
# 126              Abuja       120,369    267.51         11.40%           NGN
# 144             Kigali         1,115    151.09          3.40%           RWF
# 150              S����           121    185.09          7.90%           STN
# 152              Dakar        10,902    109.25          1.80%           XOF
# 155           Freetown         1,093    234.16         14.80%           SLL
# 159            Honiara           169    133.06          1.60%           SBD
# 160          Mogadishu           645       NaN            NaN           SOS
# 163               Juba         1,727  4,583.71        187.90%           SSP
# 166           Khartoum        20,000  1,344.19         51.00%           SDG
# 171           Dushanbe         5,310    148.57          6.00%           TJS
# 172             Dodoma        11,973    187.43          3.50%           TZS
# 175               Lom�         3,000     113.3          0.70%           XOF
# 182            Kampala         5,680    173.87          2.90%           UGX
# 192              Sanaa        10,609    157.58          8.10%           YER
# 193             Lusaka         5,141    212.31          9.20%           ZMW
# 194             Harare        10,983    105.51          0.90%           NaN
#
#      Fertility Rate Forested Area (%) Gasoline Price
# 0              4.47             2.10%         $0.70
# 4              5.52            46.30%         $0.97
# 18             4.84            37.80%         $0.72
# 26             5.19            19.30%         $0.98
# 27             5.41            10.90%         $1.21
# 28             4.65            32.70%         $0.93
# 31             4.57            39.30%         $1.03
# 33             4.72            35.60%         $1.41
# 34             5.75             3.80%         $0.78
# 38             4.21            19.70%            NaN
# 39             4.43            65.40%         $0.97
# 45             5.92            67.20%         $1.49
# 53             4.51            55.50%            NaN
# 54             4.06            14.90%         $2.00
# 57             4.25            12.50%         $0.75
# 61             3.97            90.00%         $0.92
# 62             5.22            48.40%         $1.18
# 69             4.70            25.80%         $0.90
# 70             4.48            69.80%            NaN
# 96             4.32            43.10%         $0.80
# 101            4.08            21.40%         $1.11
# 102            4.21            33.20%         $1.15
# 105            5.88             3.80%         $1.12
# 108            4.56             0.20%         $1.13
# 117            4.85            48.00%         $0.65
# 125            6.91             0.90%         $0.88
# 126            5.39             7.20%         $0.46
# 144            4.04            19.70%         $1.17
# 150            4.32            55.80%            NaN
# 152            4.63            42.80%         $1.14
# 155            4.26            43.10%         $1.08
# 159            4.40            77.90%            NaN
# 160            6.07            10.00%         $1.41
# 163            4.70               NaN         $0.28
# 166            4.41             8.10%         $0.95
# 171            3.59             3.00%         $0.71
# 172            4.89            51.60%         $0.87
# 175            4.32             3.10%         $0.71
# 182            4.96             9.70%         $0.94
# 192            3.79             1.00%         $0.92
# 193            4.63            65.20%         $1.40
# 194            3.62            35.50%         $1.34

# %% [markdown]
# 3) Utilizando loc selecciona las columnas "Country" y "Capital/Major City" de las filas donde el porcentaje de tierra agrícola (columna "Fertility Rate") es superior al 3.

# %%
df.loc[df['Fertility Rate']>3, ["Country","Capital/Major City"]]
# Out:
#                               Country Capital/Major City
# 0                         Afghanistan              Kabul
# 2                             Algeria            Algiers
# 4                              Angola             Luanda
# 18                              Benin         Porto-Novo
# 26                       Burkina Faso        Ouagadougou
# 27                            Burundi          Bujumbura
# 28                        Ivory Coast       Yamoussoukro
# 31                           Cameroon            Yaound�
# 33           Central African Republic             Bangui
# 34                               Chad          N'Djamena
# 38                            Comoros    Moroni, Comoros
# 39              Republic of the Congo        Brazzaville
# 45   Democratic Republic of the Congo           Kinshasa
# 51                              Egypt              Cairo
# 53                  Equatorial Guinea             Malabo
# 54                            Eritrea             Asmara
# 57                           Ethiopia        Addis Ababa
# 61                              Gabon         Libreville
# 62                         The Gambia             Banjul
# 65                              Ghana              Accra
# 69                             Guinea            Conakry
# 70                      Guinea-Bissau             Bissau
# 80                               Iraq            Baghdad
# 82                             Israel          Jerusalem
# 88                              Kenya            Nairobi
# 89                           Kiribati       South Tarawa
# 91                         Kyrgyzstan            Bishkek
# 95                            Lesotho             Maseru
# 96                            Liberia           Monrovia
# 101                        Madagascar       Antananarivo
# 102                            Malawi           Lilongwe
# 105                              Mali             Bamako
# 107                  Marshall Islands             Majuro
# 108                        Mauritania         Nouakchott
# 111    Federated States of Micronesia            Palikir
# 117                        Mozambique             Maputo
# 119                           Namibia           Windhoek
# 125                             Niger             Niamey
# 126                           Nigeria              Abuja
# 131                          Pakistan          Islamabad
# 135                  Papua New Guinea       Port Moresby
# 144                            Rwanda             Kigali
# 148                             Samoa               Apia
# 150                      S�����������              S����
# 152                           Senegal              Dakar
# 155                      Sierra Leone           Freetown
# 159                   Solomon Islands            Honiara
# 160                           Somalia          Mogadishu
# 163                       South Sudan               Juba
# 166                             Sudan           Khartoum
# 171                        Tajikistan           Dushanbe
# 172                          Tanzania             Dodoma
# 174                        East Timor               Dili
# 175                              Togo               Lom�
# 176                             Tonga           Nuku����
# 182                            Uganda            Kampala
# 189                           Vanuatu          Port Vila
# 192                             Yemen              Sanaa
# 193                            Zambia             Lusaka
# 194                          Zimbabwe             Harare

# %% [markdown]
# 4) Selecciona todas las filas de las columnas 0 a 4 (excluyendo la columna 4) utilizando iloc.

# %%
df.iloc[:, 0:4]
# Out:
#          Country Density\n(P/Km2) Abbreviation Agricultural Land( %)
# 0    Afghanistan               60           AF                58.10%
# 1        Albania              105           AL                43.10%
# 2        Algeria               18           DZ                17.40%
# 3        Andorra              164           AD                40.00%
# 4         Angola               26           AO                47.50%
# ..           ...              ...          ...                   ...
# 190    Venezuela               32           VE                24.50%
# 191      Vietnam              314           VN                39.30%
# 192        Yemen               56           YE                44.60%
# 193       Zambia               25           ZM                32.10%
# 194     Zimbabwe               38           ZW                41.90%
#
# [195 rows x 4 columns]

# %% [markdown]
# 5)Encuentra el valor en la fila 2 y columna 7 utilizando iloc.

# %%
df.iloc[2,7]
# Out:
# 'Algiers'

# %%
df.head()
# Out:
#        Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 0  Afghanistan               60           AF                58.10%
# 1      Albania              105           AL                43.10%
# 2      Algeria               18           DZ                17.40%
# 3      Andorra              164           AD                40.00%
# 4       Angola               26           AO                47.50%
#
#   Land Area(Km2)  Birth Rate  Calling Code Capital/Major City Co2-Emissions  \
# 0        652,230       32.49          93.0              Kabul         8,672
# 1         28,748       11.78         355.0             Tirana         4,536
# 2      2,381,741       24.28         213.0            Algiers       150,006
# 3            468        7.20         376.0   Andorra la Vella           469
# 4      1,246,700       40.73         244.0             Luanda        34,693
#
#       CPI CPI Change (%) Currency-Code  Fertility Rate Forested Area (%)  \
# 0   149.9          2.30%           AFN            4.47             2.10%
# 1  119.05          1.40%           ALL            1.62            28.10%
# 2  151.36          2.00%           DZD            3.02             0.80%
# 3     NaN            NaN           EUR            1.27            34.00%
# 4  261.73         17.10%           AOA            5.52            46.30%
#
#   Gasoline Price
# 0         $0.70
# 1         $1.36
# 2         $0.28
# 3         $1.51
# 4         $0.97

# %% [markdown]
# 6) Selecciona todas las filas para las columnas 0, 2, y 5 utilizando iloc

# %%
df.iloc[:, [0,2,5] ]
# Out:
#          Country Abbreviation  Birth Rate
# 0    Afghanistan           AF       32.49
# 1        Albania           AL       11.78
# 2        Algeria           DZ       24.28
# 3        Andorra           AD        7.20
# 4         Angola           AO       40.73
# ..           ...          ...         ...
# 190    Venezuela           VE       17.88
# 191      Vietnam           VN       16.75
# 192        Yemen           YE       30.45
# 193       Zambia           ZM       36.19
# 194     Zimbabwe           ZW       30.68
#
# [195 rows x 3 columns]

# %% [markdown]
# BONUS DE LOC Y ILOC

# %% [markdown]
# 1) Encuentra el valor de "Gasoline Price" para el país cuya abreviatura es "AL" utilizando loc.

# %%
df.loc[df['Abbreviation'].isin(['AL']), 'Gasoline Price']
# Out:
# 1    $1.36
# Name: Gasoline Price, dtype: object

# %%
gasoline_price_AL = df.loc[df['Abbreviation'] == 'AL', 'Gasoline Price'].iloc[0]
print(gasoline_price_AL)
# Out:
# $1.36

# %% [markdown]
# 2) Selecciona todas las columnas para el país cuya capital es "Tirana" utilizando loc.

# %%
df.loc[df['Capital/Major City'].isin(['Tirana']), :]
# Out:
#    Country Density\n(P/Km2) Abbreviation Agricultural Land( %) Land Area(Km2)  \
# 1  Albania              105           AL                43.10%         28,748
#
#    Birth Rate  Calling Code Capital/Major City Co2-Emissions     CPI  \
# 1       11.78         355.0             Tirana         4,536  119.05
#
#   CPI Change (%) Currency-Code  Fertility Rate Forested Area (%)  \
# 1          1.40%           ALL            1.62            28.10%
#
#   Gasoline Price
# 1         $1.36

# %% [markdown]
# 3) Filtra el conjunto de datos para mostrar solo las filas donde el índice de CPI (columna "CPI") sea igual a 128.85.

# %%
df.loc[df['CPI'].isin(['128.85']), :]
# Out:
#        Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 40  Costa Rica              100           CR                34.50%
#
#    Land Area(Km2)  Birth Rate  Calling Code Capital/Major City Co2-Emissions  \
# 40         51,100       13.97         506.0      San Jos������         8,023
#
#        CPI CPI Change (%) Currency-Code  Fertility Rate Forested Area (%)  \
# 40  128.85          2.10%           CRC            1.75            54.60%
#
#    Gasoline Price
# 40         $0.98

# %%
df['CPI'].unique()
# Out:
# array(['149.9', '119.05', '151.36', nan, '261.73', '113.81', '232.75',
#        '129.18', '119.8', '118.06', '156.32', '116.22', '117.59',
#        '179.68', '134.09', '117.11', '105.68', '110.71', '167.18',
#        '148.32', '104.9', '149.75', '167.4', '99.03', '114.42', '106.58',
#        '182.11', '111.61', '110.5', '127.63', '118.65', '116.76',
#        '186.86', '117.7', '131.91', '125.08', '140.95', '103.62',
#        '124.74', '128.85', '109.82', '102.51', '116.48', '133.85',
#        '110.35', '120.25', '103.87', '135.5', '124.14', '288.57',
#        '111.23', '124.35', '122.14', '143.86', '132.3', '112.33',
#        '110.05', '122.19', '172.73', '133.61', '112.85', '268.36',
#        '101.87', '107.43', '142.92', '262.95', '111.65', '116.19',
#        '179.29', '150.34', '121.64', '129', '180.44', '151.18', '550.93',
#        '119.86', '108.15', '110.62', '162.47', '105.48', '125.6',
#        '182.75', '180.51', '99.55', '126.6', '155.68', '135.87', '116.86',
#        '130.02', '155.86', '223.13', '125.71', '118.38', '115.09',
#        '184.33', '418.34', '121.46', '99.7', '108.73', '113.45', '135.02',
#        '129.91', '141.54', '112.1', '166.2', '195.76', '116.32', '111.07',
#        '182.31', '168.18', '157.97', '188.73', '115.91', '114.24',
#        '162.74', '109.32', '267.51', '120.27', '113.53', '182.32',
#        '118.17', '122.07', '155.99', '143.82', '129.78', '129.61',
#        '114.11', '115.38', '123.78', '180.75', '151.09', '104.57',
#        '110.13', '109.67', '117.56', '110.63', '185.09', '118.4',
#        '109.25', '144', '129.96', '234.16', '114.41', '115.34', '111.05',
#        '133.06', '158.93', '115.16', '4,583.71', '110.96', '155.53',
#        '1,344.19', '294.66', '110.51', '143.2', '148.57', '187.43',
#        '113.27', '145.38', '113.3', '121.09', '141.75', '155.33',
#        '234.44', '173.87', '281.66', '114.52', '119.62', '117.24',
#        '202.92', '117.13', '2,740.27', '163.52', '157.58', '212.31',
#        '105.51'], dtype=object)

# %% [markdown]
# 4) Encuentra la densidad (columna "Density\n(P/Km2)") para el país cuya abreviatura es "AD" utilizando loc.

# %%
df.loc[df['Abbreviation'].isin(['AD']), 'Density\n(P/Km2)']
# Out:
# 3    164
# Name: Density\n(P/Km2), dtype: object

# %%
df['Density\n(P/Km2)'].unique()
# Out:
# array(['60', '105', '18', '164', '26', '223', '17', '104', '3', '109',
#        '123', '39', '2,239', '1,265', '668', '47', '383', '108', '20',
#        '11', '64', '4', '25', '83', '76', '463', '138', '95', '56', '8',
#        '13', '153', '46', '467', '16', '100', '73', '106', '131', '139',
#        '40', '137', '43', '96', '225', '71', '103', '313', '50', '35',
#        '31', '67', '115', '49', '119', '9', '239', '57', '240', '81',
#        '331', '167', '53', '70', '414', '2,003', '89', '107', '464',
#        '151', '52', '93', '72', '400', '206', '273', '347', '7', '94',
#        '147', '34', '32', '30', '667', '238', '242', '48', '203', '99',
#        '1,802', '1,380', '329', '5', '626', '66', '784', '26,337', '2',
#        '541', '508', '55', '19', '226', '214', '15', '287', '847', '58',
#        '368', '124', '111', '248', '84', '525', '205', '301', '284',
#        '566', '228', '87', '8,358', '114', '527', '341', '219', '68',
#        '152', '110', '393', '229', '75', '118', '281', '36', '79', '314',
#        '38'], dtype=object)

# %% [markdown]
# 5)Selecciona las columnas "Country" y "Co2-Emissions".

# %%
df[['Country','Co2-Emissions']]
# Out:
#          Country Co2-Emissions
# 0    Afghanistan         8,672
# 1        Albania         4,536
# 2        Algeria       150,006
# 3        Andorra           469
# 4         Angola        34,693
# ..           ...           ...
# 190    Venezuela       164,175
# 191      Vietnam       192,668
# 192        Yemen        10,609
# 193       Zambia         5,141
# 194     Zimbabwe        10,983
#
# [195 rows x 2 columns]

# %% [markdown]
# 6) Filtra el conjunto de datos para mostrar solo las filas donde el índice de CPI cambió un 2% (columna "CPI Change (%)").

# %%
df.loc[df['CPI Change (%)'].isin(['2.00%']), :]
# Out:
#    Country Density\n(P/Km2) Abbreviation Agricultural Land( %) Land Area(Km2)  \
# 2  Algeria               18           DZ                17.40%      2,381,741
#
#    Birth Rate  Calling Code Capital/Major City Co2-Emissions     CPI  \
# 2       24.28         213.0            Algiers       150,006  151.36
#
#   CPI Change (%) Currency-Code  Fertility Rate Forested Area (%)  \
# 2          2.00%           DZD            3.02             0.80%
#
#   Gasoline Price
# 2         $0.28

# %%
df['CPI Change (%)'].unique()
# Out:
# array(['2.30%', '1.40%', '2.00%', nan, '17.10%', '1.20%', '53.50%',
#        '1.60%', '1.50%', '2.60%', '2.50%', '2.10%', '5.60%', '4.10%',
#        '-0.90%', '2.70%', '1.80%', '0.60%', '2.80%', '3.70%', '-0.40%',
#        '3.10%', '-3.20%', '-0.70%', '1.10%', '1.90%', '37.10%', '-1.00%',
#        '2.90%', '3.50%', '-4.30%', '2.20%', '0.80%', '0.30%', '3.30%',
#        '1.00%', '9.20%', '0.10%', '15.80%', '7.10%', '4.90%', '7.20%',
#        '0.20%', '9.50%', '12.50%', '4.40%', '3.00%', '7.70%', '39.90%',
#        '0.40%', '0.90%', '3.90%', '0.50%', '5.20%', '4.70%', '23.60%',
#        '1.70%', '9.40%', '0.70%', '-1.70%', '3.60%', '4.80%', '7.30%',
#        '8.80%', '5.40%', '-2.50%', '11.40%', '10.60%', '1.30%', '3.80%',
#        '4.50%', '3.40%', '7.90%', '-1.20%', '14.80%', '187.90%', '51.00%',
#        '22.00%', '36.70%', '6.00%', '7.40%', '6.70%', '15.20%', '-1.90%',
#        '7.50%', '254.90%', '8.10%'], dtype=object)

# %% [markdown]
# 7) Encuentra la tasa de natalidad (columna "Birth Rate") para el país con la abreviatura "AF" utilizando loc.

# %%
df.loc[df['Abbreviation'].isin(['AF']), 'Birth Rate']
# Out:
# 0    32.49
# Name: Birth Rate, dtype: float64

# %% [markdown]
# 8) Selecciona todas las columnas de las filas 3 a 5 (excluyendo la fila 5) utilizando iloc.

# %%
df.iloc[3:5, :]
# Out:
#    Country Density\n(P/Km2) Abbreviation Agricultural Land( %) Land Area(Km2)  \
# 3  Andorra              164           AD                40.00%            468
# 4   Angola               26           AO                47.50%      1,246,700
#
#    Birth Rate  Calling Code Capital/Major City Co2-Emissions     CPI  \
# 3        7.20         376.0   Andorra la Vella           469     NaN
# 4       40.73         244.0             Luanda        34,693  261.73
#
#   CPI Change (%) Currency-Code  Fertility Rate Forested Area (%)  \
# 3            NaN           EUR            1.27            34.00%
# 4         17.10%           AOA            5.52            46.30%
#
#   Gasoline Price
# 3         $1.51
# 4         $0.97

# %% [markdown]
# 9) Selecciona las columnas 1, 3 y 6 para todas las filas utilizando iloc.

# %%
df.iloc[:, [1,3,6]]
# Out:
#     Density\n(P/Km2) Agricultural Land( %)  Calling Code
# 0                 60                58.10%          93.0
# 1                105                43.10%         355.0
# 2                 18                17.40%         213.0
# 3                164                40.00%         376.0
# 4                 26                47.50%         244.0
# ..               ...                   ...           ...
# 190               32                24.50%          58.0
# 191              314                39.30%          84.0
# 192               56                44.60%         967.0
# 193               25                32.10%         260.0
# 194               38                41.90%         263.0
#
# [195 rows x 3 columns]
